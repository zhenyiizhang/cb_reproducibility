# %% [markdown]
# # AD Mouse Gene Expression

# %% [markdown]
# This notebook recreates the Microglia gene-expression heatmap with pattern curves from `Clean_pipeline_ad1.ipynb`.
#
# Run the final code cell to generate the figure and display it inline in the notebook.

# %%
from pathlib import Path
import sys
from IPython.display import Image, display

REPO_ROOT = Path.cwd().resolve()
while REPO_ROOT != REPO_ROOT.parent and not (REPO_ROOT / "downstream_helpers").exists():
    REPO_ROOT = REPO_ROOT.parent

HELPERS_ROOT = REPO_ROOT / "downstream_helpers"
if str(HELPERS_ROOT) not in sys.path:
    sys.path.insert(0, str(HELPERS_ROOT))

from admouse_figures import AdMouseGeneExpressionConfig, run_admouse_gene_expression_figure

# %%
config = AdMouseGeneExpressionConfig(
    output_name="admouse_gene_expression",
)
config
# Out:
# AdMouseGeneExpressionConfig(output_name='admouse_gene_expression', source_root=None, cell_type='Microglia', n_clusters=4, smooth_sigma=0.0, cluster_method='average')

# %%
result = run_admouse_gene_expression_figure(config)
assert result.figure_png_path.exists(), result.figure_png_path
display(Image(filename=str(result.figure_png_path)))
result
# Out:
# /lustre/home/2310305106/Documents/cytobridge-downstream-main/downstream_helpers/admouse_figures.py:528: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# AdMouseGeneExpressionResult(output_dir=PosixPath('/lustre/home/2310305106/Documents/cytobridge-downstream-main/results/admouse_gene_expression'), figure_pdf_path=PosixPath('/lustre/home/2310305106/Documents/cytobridge-downstream-main/results/admouse_gene_expression/microglia_combined_uniform.pdf'), figure_png_path=PosixPath('/lustre/home/2310305106/Documents/cytobridge-downstream-main/results/admouse_gene_expression/microglia_combined_uniform.png'), expr_shape=(347, 25), n_patterns=4, time_labels=('2.5', '2.8', '3.1', '3.5', '3.8', '4.1', '4.4', '4.7', '5.1', '5.4', '5.7', '6.9', '8.1', '9.4', '10.6', '11.8', '13.0', '14.2', '15.5', '16.7', '17.9', '18.7', '19.4', '20.2', '21.0'))
